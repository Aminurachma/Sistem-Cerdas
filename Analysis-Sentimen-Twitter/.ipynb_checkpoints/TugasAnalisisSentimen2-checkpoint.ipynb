# %%
import tweepy
from textblob import TextBlob
from wordcloud import WordCloud,STOPWORDS
import pandas as pd
import numpy as np
import re
import matplotlib.pyplot as plt 
plt.style.use('fivethirtyeight')

# %%
consumer_key = 'Wn02Vkt660TAWh22cGPHgYVVN'
consumer_secret = 'K00OcKr1F8hUYNjd55QEvaAsGkGVeRp95J0v1Wq8QWQGt7g9my'
access_token = '2464327753-T3QPmpnffpyjoOPQbYS97UHKr8Zokf46urNqfSf'
access_token_secret = 'tL0d6oPCl7kW0RlNxXfIPbx8UcZg9aKtIf3XeRLCMXCLa'

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)
api = tweepy.API(auth, wait_on_rate_limit=True)

# %%
post = api.user_timeline(screen_name="pilkada", count= 100, lang="en", tweet_mode="extended")

#print the last 5 tweet
print("show the 5 recents tweets: \n")

i = 1
for tweet in post[:5]:
    print(str(i)+') '+tweet.full_text + '\n')
    i = i+1
# Out:
# show the 5 recents tweets:
#
# 1) Google Alerts RSS delivery is temporarily not available. If you would like to continue receiving Google Alerts ...
#
# 2) BUKTI2 PELANGGARAN PNS DLAM PILKADA PPU http://t.co/FrGXDNQvEK http://t.co/NnWwpIeqZa
#
# 3) Google Reader is no longer available. To continue receiving Google Alerts, go to http://t.co/8pnJPmEA3a...
#
# 4) Hitung Cepat Pilkada Kota Bandung, Calon PKS-Gerindra Unggul. Pasangan Ridwan ...www.youtube.com/watch?v=wHWCCz8KeyI http://t.co/fGL7EfZTbm
#
# 5) Powerful Presentations Herman - Daud http://t.co/GVSvFvdln4 http://t.co/fbfuSmC1gd

# %%
df = pd.DataFrame([tweet.full_text for tweet in post], columns = ["Tweets"])
df.head()
# Out:
#                                               Tweets
# 0  Google Alerts RSS delivery is temporarily not ...
# 1  BUKTI2 PELANGGARAN PNS DLAM PILKADA PPU http:/...
# 2  Google Reader is no longer available. To conti...
# 3  Hitung Cepat Pilkada Kota Bandung, Calon PKS-G...
# 4  Powerful Presentations Herman - Daud http://t....

# %%
def cleanText(teks):
    teks = re.sub('@[A-Za-z0-9]+', '',teks)  #hapus @
    teks = re.sub(r'#([^\s]+)', r'\1', teks) #hapus #tagger
    teks = re.sub('RT[\s]+', '',teks)#hapus RT
    teks = re.sub('https?:\/\/\S+', '',teks)#hapus hyperlink
    teks = teks.lower() #ubah jadi lower case
    return teks

#Apply function on review column
df["Tweets"] = df["Tweets"].apply(cleanText)

df
# Out:
#                                                Tweets
# 0   google alerts rss delivery is temporarily not ...
# 1           bukti2 pelanggaran pns dlam pilkada ppu
# 2   google reader is no longer available. to conti...
# 3   hitung cepat pilkada kota bandung, calon pks-g...
# 4              powerful presentations herman - daud
# ..                                                ...
# 95  jual: spanduk pilkada, umbul-umbul, bendera..m...
# 96  prijanto saya tak akan ikut pilkada. fullscree...
# 97  the state news agency antara, quotes “cok ace”...
# 98  buy hasilpilkada just $0.11 per track full alb...
# 99  previous; next. read full article. back topilk...
#
# [100 rows x 1 columns]

# %%
def getSubjectivity(text):
    return TextBlob(text).sentiment.subjectivity

def getPolarity(text):
    return TextBlob(text).sentiment.polarity


df['Polarity'] = df["Tweets"].apply(getPolarity)
df['Subjectivity'] = df["Tweets"].apply(getSubjectivity)

df
# Out:
#                                                Tweets  Polarity  Subjectivity
# 0   google alerts rss delivery is temporarily not ... -0.200000      0.400000
# 1           bukti2 pelanggaran pns dlam pilkada ppu    0.000000      0.000000
# 2   google reader is no longer available. to conti...  0.400000      0.400000
# 3   hitung cepat pilkada kota bandung, calon pks-g...  0.000000      0.000000
# 4              powerful presentations herman - daud    0.300000      1.000000
# ..                                                ...       ...           ...
# 95  jual: spanduk pilkada, umbul-umbul, bendera..m...  0.000000      0.000000
# 96  prijanto saya tak akan ikut pilkada. fullscree...  0.000000      0.000000
# 97  the state news agency antara, quotes “cok ace”...  0.000000      0.000000
# 98  buy hasilpilkada just $0.11 per track full alb...  0.110269      0.431145
# 99  previous; next. read full article. back topilk...  0.045833      0.179167
#
# [100 rows x 3 columns]

# %%
allWords =' '.join([twts for twts in df["Tweets"]])
wc = WordCloud(width = 500 , height = 300 , random_state=10, max_font_size=110).generate(allWords)
plt.imshow(wc , interpolation = 'bilinear')
plt.axis('off')
plt.show()

# %%
#untuk menambahkan sentimen positif, negatif / netral dari polarity yg sudah dihitung
def getAnalysisSentiment(score):
    if score < 0:
        return 'Negative'
    elif score == 0:
        return 'Neutral'
    else:
        return 'Positive'
    
        
df['Analysis'] = df['Polarity'].apply(getAnalysisSentiment)

df
# Out:
#                                                Tweets  Polarity  Subjectivity  \
# 0   google alerts rss delivery is temporarily not ... -0.200000      0.400000
# 1           bukti2 pelanggaran pns dlam pilkada ppu    0.000000      0.000000
# 2   google reader is no longer available. to conti...  0.400000      0.400000
# 3   hitung cepat pilkada kota bandung, calon pks-g...  0.000000      0.000000
# 4              powerful presentations herman - daud    0.300000      1.000000
# ..                                                ...       ...           ...
# 95  jual: spanduk pilkada, umbul-umbul, bendera..m...  0.000000      0.000000
# 96  prijanto saya tak akan ikut pilkada. fullscree...  0.000000      0.000000
# 97  the state news agency antara, quotes “cok ace”...  0.000000      0.000000
# 98  buy hasilpilkada just $0.11 per track full alb...  0.110269      0.431145
# 99  previous; next. read full article. back topilk...  0.045833      0.179167
#
#     Analysis
# 0   Negative
# 1    Neutral
# 2   Positive
# 3    Neutral
# 4   Positive
# ..       ...
# 95   Neutral
# 96   Neutral
# 97   Neutral
# 98  Positive
# 99  Positive
#
# [100 rows x 4 columns]

# %%
print('Printing negative tweets: \n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False) #sorting tweets
for i in range(0, sortedDF.shape[0]):
    if(sortedDF['Analysis'][i] == 'Negative'):
        print(str(j)+ ') '+sortedDF["Tweets"][i])
        print()
        j = j+1
# Out:
# Printing negative tweets:
#
# 1) google alerts rss delivery is temporarily not available. if you would like to continue receiving google alerts ...
#
# 2) a comment on jg website on pilkada jakarta: and i thought that the obama vs romney drama in the us is bad enough...

# %%
print('Printing positive tweets: \n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False) #sorting tweets
for i in range(0, sortedDF.shape[0]):
    if(sortedDF['Analysis'][i] == 'Positive'):
        print(str(j)+ ') '+sortedDF["Tweets"][i])
        print()
        j = j+1
# Out:
# Printing positive tweets:
#
# 1) google reader is no longer available. to continue receiving google alerts, go to
#
# 2) powerful presentations herman - daud
#
# 3) powerful presentations tgb - amin ntb
#
# 4) [download file] lagu pilkada jokowi ahok free download mp3, gratis download lagu lagu pilkada jokowi ahok you ...
#
# 5) [download file] pilkada jakarta plus busway free download mp3, gratis download lagu pilkada jakarta plus buswa...
#
# 6) canda saat pilkada dki jakarta 2012 setelah hasil quick count menunjukan jokowi-ahok menang 43 % suara lawan fok...
#
# 7) free pilkada tasikmalaya mp3 download, you just click on the download link. easy way to take pilkada tasikmalaya...
#
# 8) instantly connect to what's most important to you. follow your friends, experts, favorite celebrities, and break...
#
# 9) kaos pilkada 1 - solve this fun kaos pilkada puzzle and win! at
#
# 10) instantly connect to what's most important to you. follow your friends, experts, favorite celebrities, and break...
#
# 11) instantly connect to what's most important to you. follow your friends, experts, favorite celebrities, and break...
#
# 12) instantly connect to what's most important to you. follow your friends, experts, favorite celebrities, and break...
#
# 13) ali anshori riil quick count pilkada salatigaby ali anshorino views · pengukuhan ketua bk dpr ri m prakosa ganti...
#
# 14) "tapi kalau pilkada dki menjadi ajang perebutan kekuasaan. ... read full article. back topengamat klaim pilkada ...
#
# 15) penelitian tindakan kelas, penelitian hipertensi ppt, penelitian kualitatif j moleong free, penelitian kualitati...
#
# 16) beri nilai stars, thanks! dr marcus mietzer dan pilkada aceh: dr marcus mietzner, staf pengajar senior di anu co...
#
# 17) download youmans neurosurgery, download hack webcam v51 2012, download wild ones pro trainer version 2.theworldo...
#
# 18)  jakarta: pemilihan umum kepala daerah (pilkada) dki jakarta kali ini ... read full article....
#
# 19) jual: software sms gateway pilkada software original & open
#
# 20) page 2-jual: software sms gateway pilkada software original & open
#
# 21) buy hasilpilkada just $0.11 per track full albums new mp3 releases. mp3 download. download mp3 hasilpilkada down...
#
# 22) previous; next. read full article. back topilkada jakarta kemungkinan diikuti 3 pasang calon ..... pengamat part...

# %%
print('Printing neutral tweets: \n')
j=1
sortedDF = df.sort_values(by=['Polarity'],ascending=False) #sorting tweets
for i in range(0, sortedDF.shape[0]):
    if(sortedDF['Analysis'][i] == 'Neutral'):
        print(str(j)+ ') '+sortedDF["Tweets"][i])
        print()
        j = j+1
# Out:
# Printing neutral tweets:
#
# 1) bukti2 pelanggaran pns dlam pilkada ppu
#
# 2) hitung cepat pilkada kota bandung, calon pks-gerindra unggul. pasangan ridwan ...www.youtube.com/watch?v=whwccz8keyi
#
# 3) 1:58. watch later demo pilkada lumajangby mbahasong no views · 1:38. watch ...www.youtube.com/watch?v=v5mesofzeik
#
# 4) pilkada sumsel, tps tak kesulitan prosedur 2
#
# 5) listen to jingle pilkada bandung - fahmy arsyad said by pamanami: pembuatan : april 2013 composer &amp; arranger :...
#
# 6) kpud nyatakan pasangan pastika-sudikerta menang pilkada bali [27 mei 2013]
#
# 7) rencananya pilkada gubernur jateng ini akan digelar esok, minggu (25/05/13). sehari ...www.youtube.com/watch?v...
#
# 8)  hari ini minggu, 26 mei 2013, 27 juta warga jawa ...www.youtube.com/watch?v=jsq...
#
# 9) dpr mengapresiasi kesiapan komisi pemilihan umum provinsi jawa tengah untuk ...www.youtube.com/watch?v=dghooi9nbky
#
# 10) pilkada bondowoso is on facebook. join facebook to connect with pilkada bondowoso and others you may know. fac...
#
# 11) jadi jurkam pilkada jateng, jokowi disambut his... bak bertemu selebritis, ratusan pengunjung dan pedagang pas...
#
# 12) cagub puspayoga-sukrawan (pas) unggul sementara dengan perolehan suara 57,31 ...www.youtube.com/watch?v=sxh7lakajvy
#
# 13) pusat berita —berdasarkan hasil penghitungan cepat sebuah lembaga survei, kedua ...www.youtube.com/watch?v=gb5...
#
# 14) kampanye pilkada temanggung 04by maspar ars no views · 5:46. watch ...www.youtube.com/watch?v=kbotcdgh6lm
#
# 15) pilkada jateng. kompastvinspirasi·500 videos. subscribesubscribed unsubscribe 6 ...www.youtube.com/watch?v=c_d...
#
# 16) pilkada jakarta putaran ke 2by hunesyalala 113 views; 8:02. watch later ...www.youtube.com/watch?v=yoed41uumxm
#
# 17) web sejauh mana kpu sumatera selatan mensosialisasikan pilkada ...www.youtube.com/watch?v=94rkxgv568u
#
# 18) balada pns penajam paser utara kala pilkada
#
# 19) pilkada picu kerusuhan. hastutiyani·3,858 videos. subscribesubscribed unsubscribe ...www.youtube.com/watch?v=4...
#
# 20) komisi pemilihan umum jawa barat menetapkan pasangan ahmad heryawan- deddy ...www.youtube.com/watch?v=_0dzfnrudxy
#
# 21) gathering &amp; pilkada reg.leader karesidenan madiun pada 3 maret
#
# 22) megawati protes kecurangan pilkada jabar. hastutiyani·1,568 videos. subscribe ...www.youtube.com/watch?v=mwk2yrliqa8
#
# 23) 24 feb 2013 - siaran tvri pilkada jabar 2013. fatimia rahma pratiwi·139 videos ...www.youtube.com/watch?v=lfkwiikmqea
#
# 24) get the jakarta pilkada android app (★★★★¼, 100 downloads) ⇒ buka http:// www.planet ...www.appbrain.com/app/jak...
#
# 25) oct04 baliho menjamur jelang pilkada sulbar xvid. asyhadi02. subscribe subscribed ...www.youtube.com/watch?v=rn5...
#
# 26) berdasarkan hasil survei yang dilakukan saiful mujani research and consulting (smrc ...www.youtube.com/watch?v=r...
#
# 27) berdasarkan hasil survei yang dilakukan saiful mujani research and consulting (smrc ...www.youtube.com/watch?v=r...
#
# 28) breakingnews demokrat siap menangkan foke-nara: 26/08/2012 20:41 (pilkada dki jakarta) wa...
#
# 29) wakil ketua dpr pramono anung menilai belum saatnya pemerintah menerapkan pemilu kepala daerah serentak di selur...
#
# 30) tebak skor pilkada dki, jokowi ungguli foke  by tempodotco
#
# 31)  surabaya: fenomena perolehan suara joko widodo-basuki tjahaja purnama (jokowi-ahok) dalam p...
#
# 32) pilkada 2012. today's governor election day in jakarta. did you vote? no mustache for jakarta, alright? i tried ...
#
# 33) pilkada papua atau daerah lain koq gak seheboh pilkada dki yak? media hanya hebohkan papua soal kerusuhan saja.....
#
# 34) 4 min ago. wakakakaka ahok nyembah jokowi wong jowo. cokin pengen tenar mem bebek wong jowo. wakakakaka. wong us...
#
# 35) cagub-cawagub-jokowi-ahok-pilkada-dki-2012 · cagub-cawagub-idayat- didik-pilkada-dki-2012 · cagub-cawagub-faisal...
#
# 36) dirgahayu 485 jakarta &amp; pilkada jakarta · by karangtarunamilikkitasemua 23 june 2012 jakarta1 pemilukadadki pilg...
#
# 37) detikcom ‏ 5h. follow following unfollow blocked unblock pending cancel. jelang pilkada dki, popularita...
#
# 38) pilkada dki jakarta akan digelar juli mendatang. sosialisasi pun terus digalakkan, termasuk kepada masyarakat de...
#
# 39) chairuman ikuti bhatoegana, daftar pilkada  by vivanews
#
# 40) serambi fm banda aceh pilkada damai 2012 mp3. play. download. add to playlist. send ringtonead. 14720 mins 21.49...
#
# 41) dezanovenews mendagri tak kaget dpt untuk pilkada dki berbeda dengan e-ktp
#
# 42)
#
# 43) dpt kisruh jelang pilkada kompas com. redaksi suarajakarta. subscribe subscribed ...www.youtube.com/watch?v=qn4rxyuongu
#
# 44)  bekasi selatan - komisi pemilihan umum (kpu) kota bekasi mengajukan anggran tambahan sebesa...
#
# 45) in addition, rp. 2,62 million has also been earmarked as public familiarization and security funds for dki regio...
#
# 46) laporan wartawan tribun timur / adin syekhuddin  makassar – manajer strategi pemenangan jarin...
#
# 47) cara memilih di pilkada 2012 dki jakarta, 11 juli
#
# 48) revolusi sikap pilkada dki jakarta 2012  by misisosial
#
# 49) apakah yang begini calon pemenang pemilu pilkada dki jakarta 2012 pilihanmu ?  jktketawa by...
#
# 50) jakarta (antara) - komite independen pemantau pemilu (kipp) jakarta menggelar pemantauan lapangan terhadap selur...
#
# 51) the independent elections monitoring committee (kipp) conducted a survey that ran from may 1st – 3rd regarding r...
#
# 52) _moko/pilkada-dki-2012. detikcom foke-nara lebih pilih kampanye silent operation  via ...
#
# 53) praktik politik uang terungkap jelang pilkada kota kupang. seorang warga tertangkap tangan membagi bagi-bagikan ...
#
# 54) sosialisasi pilkada dki akan digeber via sms  via  by detikcom 197291833829752832....
#
# 55) film kip aceh sosialisasi pilkada aceh1. radiogisafm. subscribe subscribed unsubscribe. loading. 14 videos. load...
#
# 56) jasa pembuatan kaos event, kaos panitia, kaos partai, kaos pilkada, polo shirt dll kaos & polo shirt.www.kaskus....
#
# 57)  jakarta - banyaknya pertanyaan mengenai perbedaan data penduduk jakarta dalam daftar pendud...
#
# 58) tempo.co , jakarta: menteri dalam negeri gamawan fauzi mengapresiasi pelaksanaan pemilihan kepala daerah di aceh...
#
# 59) in 2007 regional elections (pilkada), there were only 64.01 percent of jakarta residents who voted in pilkada. t...
#
# 60) lembaga pemantau pemilu di pilkada aceh menyebutkan ditemukan dugaan intimidasi terhadap pemilih walau tidak ber...
#
# 61) petinggi gam menangi pilkada aceh, bukti aceh cinta gam. posted in the malaysia forum. share. read. comments bel...
#
# 62) komjen pol nanan dijadwalkan daftar pilkada jabar pekan depan: wakapolri komjen pol nanan sukarna direncanakan m...
#
# 63) strategic management and business policy smu pdf mb0052. strategic management in the hospitality industry torren...
#
# 64) jayapura (antara news) - rencana pilkada di kabupaten tolikara dijadwalkan berlangsung 11 april 2012 mendatang, ...
#
# 65) pa tetap tidak ikut pilkada banda acehanalisa. ketua dewan pimpinan acehdpa partai aceh muzakir manaf menegaskan...
#
# 66) read 'pks usung hidayat-didik rachbini di pilkada dki 2012' on yahoo! news singapore.  - pks ...
#
# 67) 3 pilar pilkada. download this document for freeprintmobilecollectionsreport document. report this document. ple...
#
# 68)  - menko polhukam djoko suyanto menyatakan optimistis pelaksanaan pemilihan kepala daerah di ...
#
# 69) pilkada kok kalah greget sama lady gaga ? juni2012 celotehjkt by infojakarta
#
# 70) gubernur sumatera selatan alex noerdin mendatangi komisi pemberantasan korupsi (kpk),
#
# 71) photoshine__keygenrar. penelitian pengembangan pembelajaran pai. penelitian tentang pilkada. follow the reaper. ...
#
# 72) pilkada jakarta, pilih siapa?  via  by detikcom
#
# 73) tol cikampek padat imbas kampanye pilkada. fullscreen. news; videos; video details; video suggestions; location;...
#
# 74) jual: spanduk pilkada, umbul-umbul, bendera..masuk aja gan...!!! bisnis
#
# 75) prijanto saya tak akan ikut pilkada. fullscreen. news; videos; video details; video suggestions; location; photo...
#
# 76) the state news agency antara, quotes “cok ace” saying: “i have decided not to take part in the local elections i...

# %%
plt.figure(figsize=(8,6))
for i in range(0, df.shape[0]):
    plt.scatter(df["Polarity"][i], df["Subjectivity"][i], color="Blue")
    
plt.title('Sentiment Analysis')
plt.xlabel('Polarity')
plt.ylabel('Subjectivity')
plt.show()

# %%
ntweets = df[df.Analysis == 'Negative']
ntweets = ntweets["Tweets"]
ntweets

round( (ntweets.shape[0] /  df.shape[0]) * 100,1)
# Out:
# 2.0

# %%
df['Analysis'].value_counts()
# Out:
# Neutral     76
# Positive    22
# Negative     2
# Name: Analysis, dtype: int64

# %%
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind ='bar')
plt.show()

# %%
plt.title('Sentiment Analysis')
plt.xlabel('Sentiment')
plt.ylabel('Counts')
df['Analysis'].value_counts().plot(kind ='line')
plt.show()
